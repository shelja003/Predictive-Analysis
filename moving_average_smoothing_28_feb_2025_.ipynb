# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
df
# Out:
#         Month  MilesMM
# 0  1963-01-01     6827
# 1  1963-02-01     6178
# 2  1963-03-01     7084
# 3  1963-04-01     8162
# 4  1963-05-01     8462
# ..        ...      ...
# 91 1970-08-01    14057
# 92 1970-09-01    16234
# 93 1970-10-01    12389
# 94 1970-11-01    11595
# 95 1970-12-01    12772
#
# [96 rows x 2 columns]

# %%
df.index = df['Month']

# %%
result = seasonal_decompose(df['MilesMM'], model='multiplicative')

# %%
result.plot()

# %%
result2 = seasonal_decompose(df['MilesMM'], model='additive')
result2.plot()

# %%
result2 = seasonal_decompose(df['MilesMM'], model='multiplicative')
result2.plot()

# %%
df = pd.read_csv('/content/us-airlines-monthly-aircraft-miles-flown.csv', header=0 , parse_dates=[0])

# %%
df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
df['lag1'] = df['MilesMM'].shift(1)

# %%
df['MilesMM_diff_1'] = df['MilesMM'].diff(periods=1)

# %%
df.head()
# Out:
#        Month  MilesMM    lag1  MilesMM_diff_1
# 0 1963-01-01     6827     NaN             NaN
# 1 1963-02-01     6178  6827.0          -649.0
# 2 1963-03-01     7084  6178.0           906.0
# 3 1963-04-01     8162  7084.0          1078.0
# 4 1963-05-01     8462  8162.0           300.0

# %%
df.index = df['Month']

# %%
result = seasonal_decompose(df['MilesMM'], model='multiplacative')
result.plot()

# %%
result = seasonal_decompose(df['MilesMM'], model='multiplacative')
result.plot()
plt.show()

# %%
df.index = df['Month']
result_b = seasonal_decompose(df.iloc[1 :, 3], model='additive')
result_b.plot()
plt.show()

# %%
df['MilesMM'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df['MilesMM_diff_12'] = df['MilesMM_diff_1'].diff(periods=12)

# %%
df['MilesMM_diff_12'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
result_c = seasonal_decompose(df.iloc[13:,4], model='additive')
result_c.plot()
plt.show()

# %%
df.head(50)
# Out:
#                 Month  MilesMM     lag1  MilesMM_diff_1  MilesMM_diff_12
# Month
# 1963-01-01 1963-01-01     6827      NaN             NaN              NaN
# 1963-02-01 1963-02-01     6178   6827.0          -649.0              NaN
# 1963-03-01 1963-03-01     7084   6178.0           906.0              NaN
# 1963-04-01 1963-04-01     8162   7084.0          1078.0              NaN
# 1963-05-01 1963-05-01     8462   8162.0           300.0              NaN
# 1963-06-01 1963-06-01     9644   8462.0          1182.0              NaN
# 1963-07-01 1963-07-01    10466   9644.0           822.0              NaN
# 1963-08-01 1963-08-01    10748  10466.0           282.0              NaN
# 1963-09-01 1963-09-01     9963  10748.0          -785.0              NaN
# 1963-10-01 1963-10-01     8194   9963.0         -1769.0              NaN
# 1963-11-01 1963-11-01     6848   8194.0         -1346.0              NaN
# 1963-12-01 1963-12-01     7027   6848.0           179.0              NaN
# ...

# %%
temp_df = pd.read_csv('/content/daily-min-temperatures.xls',header=0, parse_dates=[0])

# %%
temp_df.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8
